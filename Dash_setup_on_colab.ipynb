# %% [markdown]
# <a href="https://colab.research.google.com/github/prashankkadam/Dash/blob/master/Dash_setup_on_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# How to run a Dash app in Google Colab

## Requirements

### Install ngrok
# !wget https://bin.equinox.io/c/4VmDzA7iaHb/ngrok-stable-linux-amd64.zip
# !unzip ngrok-stable-linux-amd64.zip

### Run ngrok to tunnel Dash app port 8050 to the outside world. 
### This command runs in the background.
get_ipython().system_raw('./ngrok http 8050 &')

### Get the public URL where you can access the Dash app. Copy this URL.
! curl -s http://localhost:4040/api/tunnels | python3 -c \
    "import sys, json; print(json.load(sys.stdin)['tunnels'][0]['public_url'])"

### Install Dash
# !pip install dash==0.31.1  # The core dash backend
# !pip install dash-html-components==0.13.2  # HTML components
# !pip install dash-core-components==0.39.0  # Supercharged components
# !pip install dash-table==3.1.7  # Interactive DataTable component (new!)
# Out:
# --2019-07-17 09:05:14--  https://bin.equinox.io/c/4VmDzA7iaHb/ngrok-stable-linux-amd64.zip
# Resolving bin.equinox.io (bin.equinox.io)... 52.204.136.9, 52.72.245.79, 52.200.123.104, ...
# Connecting to bin.equinox.io (bin.equinox.io)|52.204.136.9|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 13607068 (13M) [application/octet-stream]
# Saving to: ‘ngrok-stable-linux-amd64.zip’
#
# ngrok-stable-linux- 100%[===================>]  12.98M  84.4MB/s    in 0.2s
#
# 2019-07-17 09:05:14 (84.4 MB/s) - ‘ngrok-stable-linux-amd64.zip’ saved [13607068/13607068]
#
# Archive:  ngrok-stable-linux-amd64.zip
#   inflating: ngrok
# https://33322fcd.ngrok.io
# Collecting dash==0.31.1
#   Downloading https://files.pythonhosted.org/packages/84/aa/8f5a6267ab21770a71a1bcc8a3fba6bbf3a8c1725e7571a824358db8431c/dash-0.31.1.tar.gz
# Requirement already satisfied: Flask>=0.12 in /usr/local/lib/python3.6/dist-packages (from dash==0.31.1) (1.1.1)
# Collecting flask-compress (from dash==0.31.1)
#   Downloading https://files.pythonhosted.org/packages/0e/2a/378bd072928f6d92fd8c417d66b00c757dc361c0405a46a0134de6fd323d/Flask-Compress-1.4.0.tar.gz
# Requirement already satisfied: plotly in /usr/local/lib/python3.6/dist-packages (from dash==0.31.1) (3.6.1)
# Collecting dash_renderer (from dash==0.31.1)
#   Downloading https://files.pythonhosted.org/packages/c4/b2/59bfd95cce1c105fd70666eaa703b2040a4e039071b95238e9ef9c34eebc/dash_renderer-1.0.0.tar.gz (2.3MB)
#      |████████████████████████████████| 2.3MB 7.9MB/s
# Requirement already satisfied: click>=5.1 in /usr/local/lib/python3.6/dist-packages (from Flask>=0.12->dash==0.31.1) (7.0)
# Requirement already satisfied: itsdangerous>=0.24 in /usr/local/lib/python3.6/dist-packages (from Flask>=0.12->dash==0.31.1) (1.1.0)
# Requirement already satisfied: Jinja2>=2.10.1 in /usr/local/lib/python3.6/dist-packages (from Flask>=0.12->dash==0.31.1) (2.10.1)
# Requirement already satisfied: Werkzeug>=0.15 in /usr/local/lib/python3.6/dist-packages (from Flask>=0.12->dash==0.31.1) (0.15.4)
# Requirement already satisfied: nbformat>=4.2 in /usr/local/lib/python3.6/dist-packages (from plotly->dash==0.31.1) (4.4.0)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from plotly->dash==0.31.1) (1.12.0)
# Requirement already satisfied: retrying>=1.3.3 in /usr/local/lib/python3.6/dist-packages (from plotly->dash==0.31.1) (1.3.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from plotly->dash==0.31.1) (2.21.0)
# Requirement already satisfied: decorator>=4.0.6 in /usr/local/lib/python3.6/dist-packages (from plotly->dash==0.31.1) (4.4.0)
# Requirement already satisfied: pytz in /usr/local/lib/python3.6/dist-packages (from plotly->dash==0.31.1) (2018.9)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.6/dist-packages (from Jinja2>=2.10.1->Flask>=0.12->dash==0.31.1) (1.1.1)
# Requirement already satisfied: jupyter-core in /usr/local/lib/python3.6/dist-packages (from nbformat>=4.2->plotly->dash==0.31.1) (4.5.0)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /usr/local/lib/python3.6/dist-packages (from nbformat>=4.2->plotly->dash==0.31.1) (2.6.0)
# Requirement already satisfied: ipython-genutils in /usr/local/lib/python3.6/dist-packages (from nbformat>=4.2->plotly->dash==0.31.1) (0.2.0)
# Requirement already satisfied: traitlets>=4.1 in /usr/local/lib/python3.6/dist-packages (from nbformat>=4.2->plotly->dash==0.31.1) (4.3.2)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->plotly->dash==0.31.1) (2019.6.16)
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->plotly->dash==0.31.1) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->plotly->dash==0.31.1) (3.0.4)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->plotly->dash==0.31.1) (1.24.3)
# Building wheels for collected packages: dash, flask-compress, dash-renderer
#   Building wheel for dash (setup.py) ... done
#   Stored in directory: /root/.cache/pip/wheels/50/0c/6d/3a89e4f4d6b11094a08d01ea33df5fea228bf0aee1ccc5d981
#   Building wheel for flask-compress (setup.py) ... done
#   Stored in directory: /root/.cache/pip/wheels/96/32/88/a1f6d9dd3c29570ab3a8acc0d556b3b20abcf3c623c868ce0a
#   Building wheel for dash-renderer (setup.py) ... done
#   Stored in directory: /root/.cache/pip/wheels/e1/ec/40/f23ca8bba2cc56ffb3a279a660d1df7c6e1fa2557a664b660c
# Successfully built dash flask-compress dash-renderer
# Installing collected packages: flask-compress, dash-renderer, dash
# Successfully installed dash-0.31.1 dash-renderer-1.0.0 flask-compress-1.4.0
# Collecting dash-html-components==0.13.2
#   Downloading https://files.pythonhosted.org/packages/bf/9b/f3e6f121641d14bb2357e7a7208b87adfc21b7cd484444799da588df14fd/dash_html_components-0.13.2.tar.gz (236kB)
#      |████████████████████████████████| 245kB 2.8MB/s
# Requirement already satisfied: dash in /usr/local/lib/python3.6/dist-packages (from dash-html-components==0.13.2) (0.31.1)
# Requirement already satisfied: plotly in /usr/local/lib/python3.6/dist-packages (from dash->dash-html-components==0.13.2) (3.6.1)
# Requirement already satisfied: flask-compress in /usr/local/lib/python3.6/dist-packages (from dash->dash-html-components==0.13.2) (1.4.0)
# Requirement already satisfied: Flask>=0.12 in /usr/local/lib/python3.6/dist-packages (from dash->dash-html-components==0.13.2) (1.1.1)
# Requirement already satisfied: dash-renderer in /usr/local/lib/python3.6/dist-packages (from dash->dash-html-components==0.13.2) (1.0.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from plotly->dash->dash-html-components==0.13.2) (2.21.0)
# Requirement already satisfied: retrying>=1.3.3 in /usr/local/lib/python3.6/dist-packages (from plotly->dash->dash-html-components==0.13.2) (1.3.3)
# Requirement already satisfied: pytz in /usr/local/lib/python3.6/dist-packages (from plotly->dash->dash-html-components==0.13.2) (2018.9)
# Requirement already satisfied: decorator>=4.0.6 in /usr/local/lib/python3.6/dist-packages (from plotly->dash->dash-html-components==0.13.2) (4.4.0)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from plotly->dash->dash-html-components==0.13.2) (1.12.0)
# Requirement already satisfied: nbformat>=4.2 in /usr/local/lib/python3.6/dist-packages (from plotly->dash->dash-html-components==0.13.2) (4.4.0)
# Requirement already satisfied: Jinja2>=2.10.1 in /usr/local/lib/python3.6/dist-packages (from Flask>=0.12->dash->dash-html-components==0.13.2) (2.10.1)
# Requirement already satisfied: click>=5.1 in /usr/local/lib/python3.6/dist-packages (from Flask>=0.12->dash->dash-html-components==0.13.2) (7.0)
# Requirement already satisfied: itsdangerous>=0.24 in /usr/local/lib/python3.6/dist-packages (from Flask>=0.12->dash->dash-html-components==0.13.2) (1.1.0)
# Requirement already satisfied: Werkzeug>=0.15 in /usr/local/lib/python3.6/dist-packages (from Flask>=0.12->dash->dash-html-components==0.13.2) (0.15.4)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->plotly->dash->dash-html-components==0.13.2) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->plotly->dash->dash-html-components==0.13.2) (2019.6.16)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->plotly->dash->dash-html-components==0.13.2) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->plotly->dash->dash-html-components==0.13.2) (2.8)
# Requirement already satisfied: traitlets>=4.1 in /usr/local/lib/python3.6/dist-packages (from nbformat>=4.2->plotly->dash->dash-html-components==0.13.2) (4.3.2)
# Requirement already satisfied: ipython-genutils in /usr/local/lib/python3.6/dist-packages (from nbformat>=4.2->plotly->dash->dash-html-components==0.13.2) (0.2.0)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /usr/local/lib/python3.6/dist-packages (from nbformat>=4.2->plotly->dash->dash-html-components==0.13.2) (2.6.0)
# Requirement already satisfied: jupyter-core in /usr/local/lib/python3.6/dist-packages (from nbformat>=4.2->plotly->dash->dash-html-components==0.13.2) (4.5.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.6/dist-packages (from Jinja2>=2.10.1->Flask>=0.12->dash->dash-html-components==0.13.2) (1.1.1)
# Building wheels for collected packages: dash-html-components
#   Building wheel for dash-html-components (setup.py) ... done
#   Stored in directory: /root/.cache/pip/wheels/93/aa/99/a88a93e39b33d179239e0e2869bf6a093e8377bfe04e95ca8e
# Successfully built dash-html-components
# Installing collected packages: dash-html-components
# Successfully installed dash-html-components-0.13.2
# Collecting dash-core-components==0.39.0
#   Downloading https://files.pythonhosted.org/packages/a1/e5/fe391f283966c71678927da312a1d37758d4714efc7b332b174bc52c011a/dash_core_components-0.39.0.tar.gz (3.9MB)
#      |████████████████████████████████| 3.9MB 2.8MB/s
# Requirement already satisfied: dash in /usr/local/lib/python3.6/dist-packages (from dash-core-components==0.39.0) (0.31.1)
# Requirement already satisfied: plotly in /usr/local/lib/python3.6/dist-packages (from dash->dash-core-components==0.39.0) (3.6.1)
# Requirement already satisfied: dash-renderer in /usr/local/lib/python3.6/dist-packages (from dash->dash-core-components==0.39.0) (1.0.0)
# Requirement already satisfied: Flask>=0.12 in /usr/local/lib/python3.6/dist-packages (from dash->dash-core-components==0.39.0) (1.1.1)
# Requirement already satisfied: flask-compress in /usr/local/lib/python3.6/dist-packages (from dash->dash-core-components==0.39.0) (1.4.0)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from plotly->dash->dash-core-components==0.39.0) (1.12.0)
# Requirement already satisfied: retrying>=1.3.3 in /usr/local/lib/python3.6/dist-packages (from plotly->dash->dash-core-components==0.39.0) (1.3.3)
# Requirement already satisfied: decorator>=4.0.6 in /usr/local/lib/python3.6/dist-packages (from plotly->dash->dash-core-components==0.39.0) (4.4.0)
# Requirement already satisfied: nbformat>=4.2 in /usr/local/lib/python3.6/dist-packages (from plotly->dash->dash-core-components==0.39.0) (4.4.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from plotly->dash->dash-core-components==0.39.0) (2.21.0)
# Requirement already satisfied: pytz in /usr/local/lib/python3.6/dist-packages (from plotly->dash->dash-core-components==0.39.0) (2018.9)
# Requirement already satisfied: Jinja2>=2.10.1 in /usr/local/lib/python3.6/dist-packages (from Flask>=0.12->dash->dash-core-components==0.39.0) (2.10.1)
# Requirement already satisfied: Werkzeug>=0.15 in /usr/local/lib/python3.6/dist-packages (from Flask>=0.12->dash->dash-core-components==0.39.0) (0.15.4)
# Requirement already satisfied: click>=5.1 in /usr/local/lib/python3.6/dist-packages (from Flask>=0.12->dash->dash-core-components==0.39.0) (7.0)
# Requirement already satisfied: itsdangerous>=0.24 in /usr/local/lib/python3.6/dist-packages (from Flask>=0.12->dash->dash-core-components==0.39.0) (1.1.0)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /usr/local/lib/python3.6/dist-packages (from nbformat>=4.2->plotly->dash->dash-core-components==0.39.0) (2.6.0)
# Requirement already satisfied: ipython-genutils in /usr/local/lib/python3.6/dist-packages (from nbformat>=4.2->plotly->dash->dash-core-components==0.39.0) (0.2.0)
# Requirement already satisfied: traitlets>=4.1 in /usr/local/lib/python3.6/dist-packages (from nbformat>=4.2->plotly->dash->dash-core-components==0.39.0) (4.3.2)
# Requirement already satisfied: jupyter-core in /usr/local/lib/python3.6/dist-packages (from nbformat>=4.2->plotly->dash->dash-core-components==0.39.0) (4.5.0)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->plotly->dash->dash-core-components==0.39.0) (1.24.3)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->plotly->dash->dash-core-components==0.39.0) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->plotly->dash->dash-core-components==0.39.0) (2019.6.16)
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->plotly->dash->dash-core-components==0.39.0) (2.8)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.6/dist-packages (from Jinja2>=2.10.1->Flask>=0.12->dash->dash-core-components==0.39.0) (1.1.1)
# Building wheels for collected packages: dash-core-components
#   Building wheel for dash-core-components (setup.py) ... done
#   Stored in directory: /root/.cache/pip/wheels/c0/34/5a/430acb2820ad50081c36c73b8af9fa672613b6d5e0580b9c43
# Successfully built dash-core-components
# Installing collected packages: dash-core-components
# Successfully installed dash-core-components-0.39.0
# Collecting dash-table==3.1.7
#   Downloading https://files.pythonhosted.org/packages/28/a5/4e321c894012e176de0939e3ce7868790aa67acf9ce980bd4b18dacbeb35/dash_table-3.1.7.tar.gz (80kB)
#      |████████████████████████████████| 81kB 18.9MB/s
# Requirement already satisfied: dash in /usr/local/lib/python3.6/dist-packages (from dash-table==3.1.7) (0.31.1)
# Requirement already satisfied: flask-compress in /usr/local/lib/python3.6/dist-packages (from dash->dash-table==3.1.7) (1.4.0)
# Requirement already satisfied: Flask>=0.12 in /usr/local/lib/python3.6/dist-packages (from dash->dash-table==3.1.7) (1.1.1)
# Requirement already satisfied: dash-renderer in /usr/local/lib/python3.6/dist-packages (from dash->dash-table==3.1.7) (1.0.0)
# Requirement already satisfied: plotly in /usr/local/lib/python3.6/dist-packages (from dash->dash-table==3.1.7) (3.6.1)
# Requirement already satisfied: Werkzeug>=0.15 in /usr/local/lib/python3.6/dist-packages (from Flask>=0.12->dash->dash-table==3.1.7) (0.15.4)
# Requirement already satisfied: Jinja2>=2.10.1 in /usr/local/lib/python3.6/dist-packages (from Flask>=0.12->dash->dash-table==3.1.7) (2.10.1)
# Requirement already satisfied: click>=5.1 in /usr/local/lib/python3.6/dist-packages (from Flask>=0.12->dash->dash-table==3.1.7) (7.0)
# Requirement already satisfied: itsdangerous>=0.24 in /usr/local/lib/python3.6/dist-packages (from Flask>=0.12->dash->dash-table==3.1.7) (1.1.0)
# Requirement already satisfied: decorator>=4.0.6 in /usr/local/lib/python3.6/dist-packages (from plotly->dash->dash-table==3.1.7) (4.4.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from plotly->dash->dash-table==3.1.7) (2.21.0)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from plotly->dash->dash-table==3.1.7) (1.12.0)
# Requirement already satisfied: pytz in /usr/local/lib/python3.6/dist-packages (from plotly->dash->dash-table==3.1.7) (2018.9)
# Requirement already satisfied: nbformat>=4.2 in /usr/local/lib/python3.6/dist-packages (from plotly->dash->dash-table==3.1.7) (4.4.0)
# Requirement already satisfied: retrying>=1.3.3 in /usr/local/lib/python3.6/dist-packages (from plotly->dash->dash-table==3.1.7) (1.3.3)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.6/dist-packages (from Jinja2>=2.10.1->Flask>=0.12->dash->dash-table==3.1.7) (1.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->plotly->dash->dash-table==3.1.7) (2019.6.16)
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->plotly->dash->dash-table==3.1.7) (2.8)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->plotly->dash->dash-table==3.1.7) (1.24.3)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->plotly->dash->dash-table==3.1.7) (3.0.4)
# Requirement already satisfied: ipython-genutils in /usr/local/lib/python3.6/dist-packages (from nbformat>=4.2->plotly->dash->dash-table==3.1.7) (0.2.0)
# Requirement already satisfied: jupyter-core in /usr/local/lib/python3.6/dist-packages (from nbformat>=4.2->plotly->dash->dash-table==3.1.7) (4.5.0)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /usr/local/lib/python3.6/dist-packages (from nbformat>=4.2->plotly->dash->dash-table==3.1.7) (2.6.0)
# Requirement already satisfied: traitlets>=4.1 in /usr/local/lib/python3.6/dist-packages (from nbformat>=4.2->plotly->dash->dash-table==3.1.7) (4.3.2)
# Building wheels for collected packages: dash-table
#   Building wheel for dash-table (setup.py) ... done
#   Stored in directory: /root/.cache/pip/wheels/fb/8c/a1/90313671f400f0295c43f727db7900609f0dcd87d8d41a7ec4
# Successfully built dash-table
# Installing collected packages: dash-table
# Successfully installed dash-table-3.1.7

# %%
## Dash app (https://dash.plot.ly/getting-started)

### Save file with Dash app on the Google Colab machine
# %%writefile my_app1.py
import dash
import dash_core_components as dcc
import dash_html_components as html

external_stylesheets = ['https://codepen.io/chriddyp/pen/bWLwgP.css']

app = dash.Dash(__name__, external_stylesheets=external_stylesheets)

app.layout = html.Div(children=[
    html.H1(children='Hello Dash'),

    html.Div(children='''
        Dash: A web application framework for Python.
    '''),

    dcc.Graph(
        id='example-graph',
        figure={
            'data': [
                {'x': [1, 2, 3], 'y': [4, 1, 2], 'type': 'bar', 'name': 'SF'},
                {'x': [1, 2, 3], 'y': [2, 4, 5], 'type': 'bar', 'name': u'Montréal'},
            ],
            'layout': {
                'title': 'Dash Data Visualization'
            }
        }
    )
])

if __name__ == '__main__':
    app.run_server(debug=True)
# Out:
# Overwriting my_app1.py

# %%
### Run Dash app
# !python my_app1.py
# Out:
# Running on http://127.0.0.1:8050/
# Debugger PIN: 987-382-021
#  * Serving Flask app "my_app1" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: on
# Running on http://127.0.0.1:8050/
# Debugger PIN: 029-978-554
